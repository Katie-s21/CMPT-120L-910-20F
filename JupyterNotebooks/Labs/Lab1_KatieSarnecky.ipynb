# %%
name = "katie"

# %%
name
# Out:
# 'katie'

# %%
age = 20

# %%
age
# Out:
# 20

# %%
is_male = False

# %%
is_male
# Out:
# False

# %%
temperature_outside = 82.5

# %%
temperature_outside
# Out:
# 82.5

# %%
print(2 + 5)
# Out:
# 7

# %%
print(8 - 2)
# Out:
# 6

# %%
print(12 / 2)
# Out:
# 6.0

# %%
print(3 * 21)
# Out:
# 63

# %%
print(4 % 18)
# Out:
# 4

# %%
print(25 + 32)
# Out:
# 57

# %%
number_into_string = 37

# %%
print(type(number_into_string))
# Out:
# <class 'int'>

# %%
print(str(number_into_string))
# Out:
# 37

# %%
print(type(str(number_into_string)))
# Out:
# <class 'str'>

# %%
string_into_number = "10"

# %%
print(int(string_into_number))
# Out:
# 10

# %%
print(type(int(string_into_number)))
# Out:
# <class 'int'>

# %%
string_into_float = '299.99'

# %%
print(type(string_into_float))
# Out:
# <class 'str'>

# %%
print(float(string_into_float))
# Out:
# 299.99

# %%
print(type(float(string_into_float)))
# Out:
# <class 'float'>

# %%
number_into_boolean = 37

# %%
print(type(number_into_boolean))
# Out:
# <class 'int'>

# %%
print(bool(number_into_boolean))
# Out:
# True

# %%
print(type(bool(number_into_boolean)))
# Out:
# <class 'bool'>

# %%
classes = ["intro_to_programming", "three_dimensional_modeling", "ethics_and_games", "intro_to_game_design", "interactive_media"]

# %%
print(classes)
# Out:
# ['intro_to_programming', 'three_dimensional_modeling', 'ethics_and_games', 'intro_to_game_design', 'interactive_media']

# %%
classes
# Out:
# ['intro_to_programming',
#  'three_dimensional_modeling',
#  'ethics_and_games',
#  'intro_to_game_design',
#  'interactive_media']

# %%
print("the type of classes is", type(classes))
# Out:
# the type of classes is <class 'list'>
